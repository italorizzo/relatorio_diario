# %%
# !pip install pandas google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ---------------------------- --------- 256.0/341.8 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------- 341.8/341.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.5 MB 8.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.5 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/10.5 MB 9.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.5 MB 9.5 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/10.5 MB 11.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.0/10.5 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import os 
from sendEmail import *

# %%
for x in os.listdir('./images'):
    print(f'./images/{x}')
# Out:
# ./images/ABERTURA_CONTA_HIST.png
# ./images/ABERTURA_CONTA_HORA.png
# ./images/ABERTURA_CONTA_MES.png

# %%
send_message(
    destination="italo.rizzo@picpay.com",
    destination_cc='anderson.santos@picpay.com',
    subject="Teste",
    body="Teste envio de e-mail",
    attachments=os.listdir('./images')
)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=633467502736-m6hfl3634srepaudueenkog4jd8sfv07.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A56010%2F&scope=https%3A%2F%2Fmail.google.com%2F&state=f1zdPMpMCMSU9lRVJ5yMXMT73uUMVW&access_type=offline
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# ...
